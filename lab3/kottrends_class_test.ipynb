# %% [markdown]
# # KeywordOverTimeTrends Class and Method Testing
#
# This notebook is used to test and to demonstrate the usage of kottrends Engine

# %%
from kottrends import KeywordOverTimeTrends

# %%
kot = KeywordOverTimeTrends()

# %%
kot.start_search('diet')
# Out:
# INFO:kottrends:starting Keyword Over Time Sear for:diet
# INFO:kottrends:finish computing kot analysis!

# %%
kot.get_test_data()
# Out:
#             diet
# date
# 2018-01-07    89
# 2017-05-28    69
# 2016-12-18    46
# 2020-05-17    64
# 2016-03-06    72

# %%
a = kot.show_time_series_plot()

# %%
from kottrends import plt_to_html

b = plt_to_html(a)

# %%
b
# Out:
# 'data:image/png;base64,...'
